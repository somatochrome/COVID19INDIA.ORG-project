# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from datetime import date
from datetime import timedelta
import time
# %matplotlib inline
from pathlib import Path

# %%
#Specify Data folder
data_folder = Path("C:/Users/joses/Nextcloud/JOSEPH/COVID19INDIAORG ANALYSIS/PYTHON APPROACH/PYTHON CODE/data/raw data")
#Compute complete filepath for the day
file_path = data_folder / "raw_data1&2.csv"
#Read file to data frame
df=pd.read_csv(file_path)

# %%
df.head()
# Out:
#    Patient Number State Patient Number Date Announced Age Bracket Gender  \
# 0               1             KL-TS-P1     30-01-2020          20      F
# 1               2             KL-AL-P1     02-02-2020         NaN    NaN
# 2               3             KL-KS-P1     03-02-2020         NaN    NaN
# 3               4                DL-P1     02-03-2020          45      M
# 4               5                TS-P1     02-03-2020          24      M
#
#               Detected City Detected District Detected State State code  \
# 0                  Thrissur          Thrissur         Kerala         KL
# 1                 Alappuzha         Alappuzha         Kerala         KL
# 2                 Kasaragod         Kasaragod         Kerala         KL
# 3  East Delhi (Mayur Vihar)        East Delhi          Delhi         DL
# 4                 Hyderabad         Hyderabad      Telangana         TG
#
#   Current Status                                              Notes  \
# ...

# %%
df.drop(['Current Status'], axis = 1, inplace=True)
df.insert(9, column='Current Status', value="Hospitalized")

# %%
df.insert(9, column='Num Cases', value=1)
df.head()
# Out:
#    Entry_ID State Patient Number Date Announced Age Bracket Gender  \
# 0         1             KL-TS-P1     30-01-2020          20      F
# 1         2             KL-AL-P1     02-02-2020         NaN    NaN
# 2         3             KL-KS-P1     03-02-2020         NaN    NaN
# 3         4                DL-P1     02-03-2020          45      M
# 4         5                TS-P1     02-03-2020          24      M
#
#               Detected City Detected District Detected State State code  \
# 0                  Thrissur          Thrissur         Kerala         KL
# 1                 Alappuzha         Alappuzha         Kerala         KL
# 2                 Kasaragod         Kasaragod         Kerala         KL
# 3  East Delhi (Mayur Vihar)        East Delhi          Delhi         DL
# 4                 Hyderabad         Hyderabad      Telangana         TG
#
#    Num Cases Current Status  \
# 0          1      Recovered
# 1          1      Recovered
# 2          1      Recovered
# ...

# %%
df.tail()
# Out:
#        Patient Number State Patient Number Date Announced Age Bracket Gender  \
# 27885           27887                  NaN     26-04-2020         NaN    NaN
# 27886           27888                  NaN     26-04-2020         NaN    NaN
# 27887           27889                  NaN     26-04-2020          12      F
# 27888           27890                  NaN     26-04-2020          13      F
# 27889           27891                  NaN     26-04-2020          17      F
#
#       Detected City Detected District Detected State State code  Num Cases  \
# 27885           NaN               NaN          Delhi         DL          1
# 27886           NaN               NaN    Uttarakhand         UT          1
# 27887           NaN            Munger          Bihar         BR          1
# 27888           NaN            Munger          Bihar         BR          1
# 27889           NaN            Munger          Bihar         BR          1
#
#       Current Status            Notes  \
# ...

# %%
df.rename(columns={'Patient Number':'Entry_ID'}, inplace=True)
df.head()
# Out:
#    Entry_ID State Patient Number Date Announced Age Bracket Gender  \
# 0         1             KL-TS-P1     30-01-2020          20      F
# 1         2             KL-AL-P1     02-02-2020         NaN    NaN
# 2         3             KL-KS-P1     03-02-2020         NaN    NaN
# 3         4                DL-P1     02-03-2020          45      M
# 4         5                TS-P1     02-03-2020          24      M
#
#               Detected City Detected District Detected State State code  \
# 0                  Thrissur          Thrissur         Kerala         KL
# 1                 Alappuzha         Alappuzha         Kerala         KL
# 2                 Kasaragod         Kasaragod         Kerala         KL
# 3  East Delhi (Mayur Vihar)        East Delhi          Delhi         DL
# 4                 Hyderabad         Hyderabad      Telangana         TG
#
#   Current Status                                              Notes  \
# ...

# %%
df.tail()
# Out:
#        Entry_ID State Patient Number Date Announced Age Bracket Gender  \
# 27885     27887                  NaN     26-04-2020         NaN    NaN
# 27886     27888                  NaN     26-04-2020         NaN    NaN
# 27887     27889                  NaN     26-04-2020          12      F
# 27888     27890                  NaN     26-04-2020          13      F
# 27889     27891                  NaN     26-04-2020          17      F
#
#       Detected City Detected District Detected State State code  Num Cases  \
# 27885           NaN               NaN          Delhi         DL          1
# 27886           NaN               NaN    Uttarakhand         UT          1
# 27887           NaN            Munger          Bihar         BR          1
# 27888           NaN            Munger          Bihar         BR          1
# 27889           NaN            Munger          Bihar         BR          1
#
#       Current Status            Notes  \
# 27885   Hospitalized  Details awaited
# ...

# %%
file_path2 = data_folder / "raw_data3.csv"
#Read file to data frame
df2=pd.read_csv(file_path2)
df2.head()
# Out:
#    Entry_ID State Patient Number Date Announced  Age Bracket Gender  \
# 0       1.0                  NaN     27/04/2020          NaN    NaN
# 1       2.0                  NaN     27/04/2020          NaN    NaN
# 2       3.0                  NaN     27/04/2020          NaN    NaN
# 3       4.0                  NaN     27/04/2020         28.0      M
# 4       5.0                  NaN     27/04/2020          NaN    NaN
#
#   Detected City Detected District Detected State State code  Num Cases  \
# 0           NaN               NaN    West Bengal         WB         38
# 1           NaN          Bhilwara      Rajasthan         RJ          2
# 2           NaN            Jaipur      Rajasthan         RJ          9
# 3      Surajpol            Jaipur      Rajasthan         RJ          1
# 4           NaN         Jaisalmer      Rajasthan         RJ          1
#
#   Current Status Contracted from which Patient (Suspected)            Notes  \
# ...

# %%
df.drop(['State Patient Number', 'Contracted from which Patient (Suspected)', 'Backup Notes', 'Source_1', 'Source_2', 'Source_3', 'Type of transmission'], axis = 1, inplace=True)

# %%
df.drop(['Notes'], axis=1, inplace=True)
df.head()
# Out:
#    Entry_ID Date Announced Age Bracket Gender             Detected City  \
# 0         1     30-01-2020          20      F                  Thrissur
# 1         2     02-02-2020         NaN    NaN                 Alappuzha
# 2         3     03-02-2020         NaN    NaN                 Kasaragod
# 3         4     02-03-2020          45      M  East Delhi (Mayur Vihar)
# 4         5     02-03-2020          24      M                 Hyderabad
#
#   Detected District Detected State State code  Num Cases Current Status  \
# 0          Thrissur         Kerala         KL          1      Recovered
# 1         Alappuzha         Kerala         KL          1      Recovered
# 2         Kasaragod         Kerala         KL          1      Recovered
# 3        East Delhi          Delhi         DL          1      Recovered
# 4         Hyderabad      Telangana         TG          1      Recovered
#
#   Nationality Status Change Date
# 0       India         14-02-2020
# ...

# %%
df2.drop(['State Patient Number', 'Contracted from which Patient (Suspected)', 'Notes', 'Source_1', 'Source_2', 'Source_3', 'Type of transmission'], axis = 1, inplace=True)
df2.head()
# Out:
#    Entry_ID Date Announced  Age Bracket Gender Detected City  \
# 0       1.0     27/04/2020          NaN    NaN           NaN
# 1       2.0     27/04/2020          NaN    NaN           NaN
# 2       3.0     27/04/2020          NaN    NaN           NaN
# 3       4.0     27/04/2020         28.0      M      Surajpol
# 4       5.0     27/04/2020          NaN    NaN           NaN
#
#   Detected District Detected State State code  Num Cases Current Status  \
# 0               NaN    West Bengal         WB         38   Hospitalized
# 1          Bhilwara      Rajasthan         RJ          2   Hospitalized
# 2            Jaipur      Rajasthan         RJ          9   Hospitalized
# 3            Jaipur      Rajasthan         RJ          1       Deceased
# 4         Jaisalmer      Rajasthan         RJ          1   Hospitalized
#
#    Nationality  Status Change Date
# 0          NaN                 NaN
# 1          NaN                 NaN
# 2          NaN                 NaN
# ...

# %%
frames=[df, df2]
df3=pd.concat(frames)
df3.head()
# Out:
#    Entry_ID Date Announced Age Bracket Gender             Detected City  \
# 0       1.0     30-01-2020          20      F                  Thrissur
# 1       2.0     02-02-2020         NaN    NaN                 Alappuzha
# 2       3.0     03-02-2020         NaN    NaN                 Kasaragod
# 3       4.0     02-03-2020          45      M  East Delhi (Mayur Vihar)
# 4       5.0     02-03-2020          24      M                 Hyderabad
#
#   Detected District Detected State State code  Num Cases Current Status  \
# 0          Thrissur         Kerala         KL          1      Recovered
# 1         Alappuzha         Kerala         KL          1      Recovered
# 2         Kasaragod         Kerala         KL          1      Recovered
# 3        East Delhi          Delhi         DL          1      Recovered
# 4         Hyderabad      Telangana         TG          1      Recovered
#
#   Nationality Status Change Date
# 0       India         14-02-2020
# ...

# %%
df3.tail()
# Out:
#       Entry_ID Date Announced Age Bracket Gender Detected City  \
# 3300    3301.0     03/05/2020         NaN    NaN           NaN
# 3301    3302.0     03/05/2020         NaN    NaN           NaN
# 3302    3303.0     03/05/2020         NaN    NaN           NaN
# 3303    3304.0     03/05/2020          34      M           NaN
# 3304       NaN            NaN         NaN    NaN           NaN
#
#      Detected District Detected State State code  Num Cases Current Status  \
# 3300         Jhunjhunu      Rajasthan         RJ          1      Recovered
# 3301            Nagaur      Rajasthan         RJ          3      Recovered
# 3302            Jaipur      Rajasthan         RJ          2       Deceased
# 3303          Balasore         Odisha         OR          1   Hospitalized
# 3304               NaN        Haryana         HR         45   Hospitalized
#
#      Nationality Status Change Date
# 3300         NaN                NaN
# 3301         NaN                NaN
# ...

# %%
df3.describe()
# Out:
#            Entry_ID     Num Cases
# count  31194.000000  31195.000000
# mean   12644.206290      1.438147
# std     8507.055105      8.953599
# min        1.000000    -27.000000
# 25%     4496.250000      1.000000
# 50%    12294.500000      1.000000
# 75%    20092.750000      1.000000
# max    27891.000000    751.000000

# %%
#Specify Export folder 
export_folder =Path("C:/Users/joses/Nextcloud/JOSEPH/COVID19INDIAORG ANALYSIS/PYTHON APPROACH/PYTHON CODE/exports")
fname="raw_data.csv"
file_path3= export_folder / fname
file_path3
# Out:
# WindowsPath('C:/Users/joses/Nextcloud/JOSEPH/COVID19INDIAORG ANALYSIS/PYTHON APPROACH/PYTHON CODE/exports/raw_data.csv')

# %%
df3.to_csv(file_path3)
